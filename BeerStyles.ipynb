# %%
import re
import pandas as pd
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
beers_csv = "beers.csv"
breweries_csv = "breweries.csv"

beers_df = pd.read_csv(beers_csv)
breweries_df = pd.read_csv(breweries_csv)
beers_df.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
breweries_df = breweries_df.rename(columns={"Unnamed: 0":"brewery_id"})
breweries_df
# Out:
#      brewery_id                           name           city state
# 0             0             NorthGate Brewing     Minneapolis    MN
# 1             1      Against the Grain Brewery     Louisville    KY
# 2             2       Jack's Abby Craft Lagers     Framingham    MA
# 3             3      Mike Hess Brewing Company      San Diego    CA
# 4             4        Fort Point Beer Company  San Francisco    CA
# ..          ...                            ...            ...   ...
# 553         553            Covington Brewhouse      Covington    LA
# 554         554                Dave's Brewfarm         Wilson    WI
# 555         555          Ukiah Brewing Company          Ukiah    CA
# 556         556        Butternuts Beer and Ale  Garrattsville    NY
# 557         557  Sleeping Lady Brewing Company      Anchorage    AK
#
# [558 rows x 4 columns]

# %%
# pd.merge(beers_df, breweries_df, )
poop_df = breweries_df.merge(beers_df, on="brewery_id")
poop_df
# Out:
#       brewery_id                         name_x           city state  \
# 0              0             NorthGate Brewing     Minneapolis    MN
# 1              0             NorthGate Brewing     Minneapolis    MN
# 2              0             NorthGate Brewing     Minneapolis    MN
# 3              0             NorthGate Brewing     Minneapolis    MN
# 4              0             NorthGate Brewing     Minneapolis    MN
# ...          ...                            ...            ...   ...
# 2405         556        Butternuts Beer and Ale  Garrattsville    NY
# 2406         556        Butternuts Beer and Ale  Garrattsville    NY
# 2407         556        Butternuts Beer and Ale  Garrattsville    NY
# 2408         556        Butternuts Beer and Ale  Garrattsville    NY
# 2409         557  Sleeping Lady Brewing Company      Anchorage    AK
#
#       Unnamed: 0    abv   ibu    id                     name_y  \
# 0           1493  0.045  50.0  2692               Get Together
# 1           1494  0.049  26.0  2691              Maggie's Leap
# 2           1495  0.048  19.0  2690                 Wall's End
# 3           1496  0.060  38.0  2689                    Pumpion
# 4           1497  0.060  25.0  2688                 Stronghold
# ...          ...    ...   ...   ...                        ...
# 2405         488  0.049   NaN    52   Heinnieweisse Weissebier
# 2406         489  0.068   NaN    51            Snapperhead IPA
# 2407         490  0.049   NaN    50          Moo Thunder Stout
# 2408         491  0.043   NaN    49          Porkslap Pale Ale
# 2409        1897  0.049   NaN    30  Urban Wilderness Pale Ale
#
#                         style  ounces
# 0                American IPA    16.0
# 1          Milk / Sweet Stout    16.0
# 2           English Brown Ale    16.0
# 3                 Pumpkin Ale    16.0
# 4             American Porter    16.0
# ...                       ...     ...
# 2405               Hefeweizen    12.0
# 2406             American IPA    12.0
# 2407       Milk / Sweet Stout    12.0
# 2408  American Pale Ale (APA)    12.0
# 2409         English Pale Ale    12.0
#
# [2410 rows x 11 columns]

# %%
beers_and_breweries = pd.merge(beers_df, 
                               breweries_df, 
                               how='inner', 
                               left_on="brewery_id", 
                               right_on="id", 
                               sort=True,
                               suffixes=('_beer', '_brewery'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-2036d40c4bd0> in <module>
# ----> 1 beers_and_breweries = pd.merge(beers_df,
#       2                                breweries_df,
#       3                                how='inner',
#       4                                left_on="brewery_id",
#       5                                right_on="id",
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
#     654         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1003                     if not is_rkey(rk):
#    1004                         if rk is not None:
# -> 1005                             right_keys.append(right._get_label_or_level_values(rk))
#    1006                         else:
#    1007                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
#    1564
#    1565         # Check for duplicates
#
# KeyError: 'id'

# %%
beers.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-77f8d5f3781c> in <module>
# ----> 1 beers.dtypes
#
# NameError: name 'beers' is not defined

# %%
def get_var_category(series):
    unique_count = series.nunique(dropna=False)
    total_count = len(series)
    if pd.api.types.is_numeric_dtype(series):
        return 'Numerical'
    elif pd.api.types.is_datetime64_dtype(series):
        return 'Date'
    elif unique_count==total_count:
        return 'Text (Unique)'
    else:
        return 'Categorical'

def print_categories(df):
    for column_name in df.columns:
        print(column_name, ": ", get_var_category(df[column_name]))

# %%
print_categories(beers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-29f04dd426f6> in <module>
# ----> 1 print_categories(beers)
#
# NameError: name 'beers' is not defined

# %%
brew_group = poop_df.groupby('style')

# %%
count_brew = brew_group['style'].count()

count_brew
# Out:
# style
# Abbey Single Ale                2
# Altbier                        13
# American Adjunct Lager         18
# American Amber / Red Ale      133
# American Amber / Red Lager     29
#                              ...
# Tripel                         11
# Vienna Lager                   20
# Wheat Ale                       1
# Winter Warmer                  15
# Witbier                        51
# Name: style, Length: 99, dtype: int64

# %%
state_data = poop_df["state"].value_counts()
style_data = poop_df["style"].value_counts()

# %%
style_state_data= state_data.add(style_data, fill_value=0)

# %%
style_chart = style_data.plot(kind='bar', facecolor="blue", figsize=(30,5))
plt.title("Style Brewed Popularity")
state_chart.set_xlabel("Style")
state_chart.set_ylabel("Number of Times Brewed")
plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
state_data = poop_df["state"].value_counts()

# %%
state_chart = state_data.plot(kind='bar', facecolor="blue", figsize=(10,5))
plt.title("State Brewery Popularity")
state_chart.set_xlabel("State")
state_chart.set_ylabel("Number of Breweries")
plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
state_and_style = poop_df[["state","style"]]
state_and_style = state_and_style.set_index("state")
state_and_style
# Out:
#                          style
# state
#  MN               American IPA
#  MN         Milk / Sweet Stout
#  MN          English Brown Ale
#  MN                Pumpkin Ale
#  MN            American Porter
# ...                        ...
#  NY                 Hefeweizen
#  NY               American IPA
#  NY         Milk / Sweet Stout
#  NY    American Pale Ale (APA)
#  AK           English Pale Ale
#
# [2410 rows x 1 columns]

# %%
state_and_style_df = pd.DataFrame(state_and_style)

# %%
plt.style.use('ggplot')

state_and_style_df.groupby(['state', 'style'])\
      .style.count().unstack().plot.bar(legend=True, figsize=(50,10))

# %%
abv_and_style = poop_df[["abv","style"]]
abv_and_style = state_and_style.set_index("style")
abv_and_style
# Out:
# Empty DataFrame
# Columns: []
# Index: [American IPA, Milk / Sweet Stout, English Brown Ale, Pumpkin Ale, American Porter, Extra Special / Strong Bitter (ESB), American Double / Imperial IPA, English Barleywine, Milk / Sweet Stout, American Pale Ale (APA), German Pilsener, Pumpkin Ale, Belgian Pale Ale, American Pilsner, American Double / Imperial IPA, Saison / Farmhouse Ale, American Wild Ale, American IPA, English Brown Ale, Keller Bier / Zwickel Bier, American Pale Lager, American India Pale Lager, American India Pale Lager, American India Pale Lager, American Double / Imperial IPA, American IPA, Wheat Ale, American Double / Imperial IPA, Cream Ale, Kölsch, American Pale Wheat Ale, American Amber / Red Ale, Kölsch, American IPA, American Double / Imperial Stout, American Brown Ale, American Pale Ale (APA), Kölsch, American IPA, American Double / Imperial IPA, American Pale Ale (APA), Old Ale, American Pale Wheat Ale, American IPA, Tripel, American IPA, Russian Imperial Stout, Saison / Farmhouse Ale, American IPA, American Porter, American IPA, Witbier, American Stout, American IPA, American Pale Ale (APA), Saison / Farmhouse Ale, Belgian Pale Ale, American Double / Imperial Stout, American IPA, Rauchbier, Bière de Garde, Belgian IPA, Doppelbock, Saison / Farmhouse Ale, Witbier, Belgian IPA, Saison / Farmhouse Ale, Belgian IPA, Saison / Farmhouse Ale, Rye Beer, Dunkelweizen, Belgian Strong Pale Ale, Dubbel, Belgian Dark Ale, Belgian Dark Ale, Belgian Pale Ale, Witbier, Oatmeal Stout, American Porter, Quadrupel (Quad), Rauchbier, Belgian IPA, Belgian Dark Ale, Belgian IPA, Rye Beer, American Stout, Fruit / Vegetable Beer, Belgian Dark Ale, Belgian Dark Ale, Belgian Pale Ale, Bière de Garde, Belgian Dark Ale, Witbier, American Stout, Belgian IPA, American Wild Ale, Fruit / Vegetable Beer, American Double / Imperial IPA, Bière de Garde, American Black Ale, ...]
#
# [2410 rows x 0 columns]

# %%
state_and_style = poop_df[["state","style"]]
state_and_style = state_and_style.set_index("state")
state_and_style
# Out:
#                          style
# state
#  MN               American IPA
#  MN         Milk / Sweet Stout
#  MN          English Brown Ale
#  MN                Pumpkin Ale
#  MN            American Porter
# ...                        ...
#  NY                 Hefeweizen
#  NY               American IPA
#  NY         Milk / Sweet Stout
#  NY    American Pale Ale (APA)
#  AK           English Pale Ale
#
# [2410 rows x 1 columns]

# %%
poop_df.nlargest(5, ['abv'])
# Out:
#      brewery_id                     name_x        city state  Unnamed: 0  \
# 374          51    Upslope Brewing Company     Boulder    CO        2278
# 7             1  Against the Grain Brewery  Louisville    KY          70
# 143          17    Tin Man Brewing Company  Evansville    IN        2189
# 375          51    Upslope Brewing Company     Boulder    CO        2279
# 335          46        Sixpoint Craft Ales    Brooklyn    NY        1857
#
#        abv   ibu    id                                             name_y  \
# 374  0.128   NaN  2565  Lee Hill Series Vol. 5 - Belgian Style Quadrup...
# 7    0.125  80.0  2685                                     London Balling
# 143  0.120  90.0  2621                                               Csar
# 375  0.104   NaN  2564   Lee Hill Series Vol. 4 - Manhattan Style Rye Ale
# 335  0.100  52.0  2574                                             4Beans
#
#                       style  ounces
# 374        Quadrupel (Quad)    19.2
# 7        English Barleywine    16.0
# 143  Russian Imperial Stout    16.0
# 375                Rye Beer    19.2
# 335           Baltic Porter    12.0

# %%
top_5 = poop_df.nlargest(5, ['abv'])

# %%
top_5 = top_5[["style","abv"]]
top_5 = top_5.set_index("style")
top_5
# Out:
#                           abv
# style
# Quadrupel (Quad)        0.128
# English Barleywine      0.125
# Russian Imperial Stout  0.120
# Rye Beer                0.104
# Baltic Porter           0.100

# %%
#state_chart = state_data.plot(kind='bar', facecolor="blue", figsize=(10,5))
# plt.title("State Brewery Popularity")
# state_chart.set_xlabel("State")
# state_chart.set_ylabel("Number of Breweries")
# plt.show()
# plt.tight_layout

xlabel = 'style'
ylabel = 'abv'
top_5_chart = top_5.plot(kind='bar', facecolor="blue", figsize=(10,5))
plt.title("ABV by style")
top_5_chart.set_xlabel("style")
top_5_chart.set_ylabel("abv")
plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
abv_and_style = poop_df[["style","abv"]]
abv_and_style = abv_and_style.set_index("style")
abv_and_style
# Out:
#                            abv
# style
# American IPA             0.045
# Milk / Sweet Stout       0.049
# English Brown Ale        0.048
# Pumpkin Ale              0.060
# American Porter          0.060
# ...                        ...
# Hefeweizen               0.049
# American IPA             0.068
# Milk / Sweet Stout       0.049
# American Pale Ale (APA)  0.043
# English Pale Ale         0.049
#
# [2410 rows x 1 columns]

# %%
new_poop_df=poop_df.dropna()
new_poop_df
# Out:
#       brewery_id                     name_x         city state  Unnamed: 0  \
# 0              0         NorthGate Brewing   Minneapolis    MN        1493
# 1              0         NorthGate Brewing   Minneapolis    MN        1494
# 2              0         NorthGate Brewing   Minneapolis    MN        1495
# 3              0         NorthGate Brewing   Minneapolis    MN        1496
# 4              0         NorthGate Brewing   Minneapolis    MN        1497
# ...          ...                        ...          ...   ...         ...
# 2386         544          Pyramid Breweries      Seattle    WA        1677
# 2387         545  Lancaster Brewing Company    Lancaster    PA        1189
# 2388         545  Lancaster Brewing Company    Lancaster    PA        1190
# 2389         546    Upstate Brewing Company       Elmira    NY        2296
# 2390         546    Upstate Brewing Company       Elmira    NY        2297
#
#         abv   ibu    id                            name_y  \
# 0     0.045  50.0  2692                      Get Together
# 1     0.049  26.0  2691                     Maggie's Leap
# 2     0.048  19.0  2690                        Wall's End
# 3     0.060  38.0  2689                           Pumpion
# 4     0.060  25.0  2688                        Stronghold
# ...     ...   ...   ...                               ...
# 2386  0.052  18.0    82         Haywire Hefeweizen (2010)
# 2387  0.066  30.0   392            Rumspringa Golden Bock
# 2388  0.048  28.0   195     Lancaster German Style Kölsch
# 2389  0.053  22.0   382  Common Sense Kentucky Common Ale
# 2390  0.065  70.0   381                    Upstate I.P.W.
#
#                       style  ounces
# 0              American IPA    16.0
# 1        Milk / Sweet Stout    16.0
# 2         English Brown Ale    16.0
# 3               Pumpkin Ale    16.0
# 4           American Porter    16.0
# ...                     ...     ...
# 2386             Hefeweizen    16.0
# 2387  Maibock / Helles Bock    12.0
# 2388                 Kölsch    12.0
# 2389     American Brown Ale    16.0
# 2390           American IPA    12.0
#
# [1403 rows x 11 columns]

# %%
sorted_poop_df=new_poop_df.sort_values(by='abv', ascending=False)
sorted_poop_df
# Out:
#       brewery_id                            name_x             city state  \
# 7              1         Against the Grain Brewery       Louisville    KY
# 143           17           Tin Man Brewing Company       Evansville    IN
# 335           46               Sixpoint Craft Ales         Brooklyn    NY
# 207           25          Sun King Brewing Company     Indianapolis    IN
# 1017         166               Oskar Blues Brewery         Longmont    CO
# ...          ...                               ...              ...   ...
# 338           46               Sixpoint Craft Ales         Brooklyn    NY
# 764          129                    Straub Brewery        St Mary's    PA
# 2338         528         Asheville Brewing Company        Asheville    NC
# 669          109  Woodstock Inn, Station & Brewery  North Woodstock    NH
# 515           80            Hopworks Urban Brewery         Portland    OR
#
#       Unnamed: 0    abv    ibu    id                name_y  \
# 7             70  0.125   80.0  2685        London Balling
# 143         2189  0.120   90.0  2621                  Csar
# 335         1857  0.100   52.0  2574                4Beans
# 207         2066  0.099   60.0   394  Johan the Barleywine
# 1017        1580  0.099  100.0     6    GUBNA Imperial IPA
# ...          ...    ...    ...   ...                   ...
# 338         1860  0.032    7.0  2266                   Rad
# 764         2027  0.032   13.0  2231        American Light
# 2338         138  0.032   27.0   550           Rocket Girl
# 669         2394  0.028   15.0  2306           Summer Brew
# 515         1074  0.027   21.0  2482        Totally Radler
#
#                                style  ounces
# 7                 English Barleywine    16.0
# 143           Russian Imperial Stout    16.0
# 335                    Baltic Porter    12.0
# 207               English Barleywine    16.0
# 1017  American Double / Imperial IPA    12.0
# ...                              ...     ...
# 338           Fruit / Vegetable Beer    16.0
# 764                      Light Lager    12.0
# 2338                          Kölsch    12.0
# 669                 American Pilsner    12.0
# 515                           Radler    16.0
#
# [1403 rows x 11 columns]

# %%
# top_5 = poop_df.nlargest(5, ['abv'])
top_30 = new_poop_df.nlargest(30, ['abv'])
top_30
# Out:
#       brewery_id                               name_x                city  \
# 7              1            Against the Grain Brewery          Louisville
# 143           17              Tin Man Brewing Company          Evansville
# 335           46                  Sixpoint Craft Ales            Brooklyn
# 166           24                     Burn 'Em Brewing       Michigan City
# 178           25             Sun King Brewing Company        Indianapolis
# 190           25             Sun King Brewing Company        Indianapolis
# 196           25             Sun King Brewing Company        Indianapolis
# 207           25             Sun King Brewing Company        Indianapolis
# 261           33           The Dudes' Brewing Company            Torrance
# 341           46                  Sixpoint Craft Ales            Brooklyn
# 348           46                  Sixpoint Craft Ales            Brooklyn
# 377           51              Upslope Brewing Company             Boulder
# 382           51              Upslope Brewing Company             Boulder
# 423           61                Surly Brewing Company     Brooklyn Center
# 673          110             Renegade Brewing Company              Denver
# 702          118        Southern Star Brewing Company              Conroe
# 755          128             Real Ale Brewing Company              Blanco
# 1015         166                  Oskar Blues Brewery            Longmont
# 1017         166                  Oskar Blues Brewery            Longmont
# 1271         222               Carton Brewing Company  Atlantic Highlands
# 1303         230             Cape Ann Brewing Company          Gloucester
# 1605         309              Sockeye Brewing Company               Boise
# 1721         346            Manzanita Brewing Company              Santee
# 1813         368               21st Amendment Brewery       San Francisco
# 1933         389  Oskar Blues Brewery (North Carol...             Brevard
# 2038         423                 Hess Brewing Company           San Diego
# 2107         444                     Big Wood Brewery     Vadnais Heights
# 2274         503                  Oskar Blues Brewery               Lyons
# 2108         444                     Big Wood Brewery     Vadnais Heights
# 430           61                Surly Brewing Company     Brooklyn Center
#
#      state  Unnamed: 0    abv    ibu    id  \
# 7       KY          70  0.125   80.0  2685
# 143     IN        2189  0.120   90.0  2621
# 335     NY        1857  0.100   52.0  2574
# 166     IN         479  0.099  115.0  2471
# 178     IN        2037  0.099   36.0  2083
# 190     IN        2049  0.099   75.0  1367
# 196     IN        2055  0.099   60.0  1049
# 207     IN        2066  0.099   60.0   394
# 261     CA        2160  0.099  101.0  1561
# 341     NY        1863  0.099  111.0  1696
# 348     NY        1870  0.099   85.0  1020
# 377     CO        2281  0.099   51.0  2562
# 382     CO        2286  0.099   90.0  1315
# 423     MN        2074  0.099   85.0  1739
# 673     CO        1709  0.099  100.0  1006
# 702     TX        1962  0.099  100.0   853
# 755     TX        1684  0.099   85.0  1861
# 1015    CO        1578  0.099   98.0     8
# 1017    CO        1580  0.099  100.0     6
# 1271    NJ         548  0.099  100.0  2094
# 1303    MA         524  0.099   43.0  2068
# 1605    ID        1931  0.099  100.0  1160
# 1721    CA        1268  0.099   93.0  1674
# 1813    CA          21  0.099   92.0  1036
# 1933    NC        1598  0.099   98.0  1532
# 2038    CA        1045  0.099   85.0   904
# 2107    MN         267  0.099   85.0  1256
# 2274    CO        1586  0.099   98.0   803
# 2108    MN         268  0.098   76.0  1255
# 430     MN        2081  0.097  120.0    15
#
#                                                  name_y  \
# 7                                        London Balling
# 143                                                Csar
# 335                                              4Beans
# 166                                    Hopkick Dropkick
# 178    Bourbon Barrel Batch 666: Sympathy for the Devil
# 190                          Bourbon Barrel Aged Timmie
# 196                                Bourbon Barrel Johan
# 207                                Johan the Barleywine
# 261                                        Double Trunk
# 341                                              Hi-Res
# 348                                              3Beans
# 377   Lee Hill Series Vol. 3 - Barrel Aged Imperial ...
# 382                     Upslope Imperial India Pale Ale
# 423                                              BLAKKR
# 673                     Elevation Triple India Pale Ale
# 702                                PRO-AM (2012) (2012)
# 755                                              BLAKKR
# 1015                            Ten Fidy Imperial Stout
# 1017                                 GUBNA Imperial IPA
# 1271                                            Epitome
# 1303                             Imperial Pumpkin Stout
# 1605                                  Old Devil's Tooth
# 1721                                 Chaotic Double IPA
# 1813                                      Lower De Boom
# 1933                                           Ten Fidy
# 2038                       Ex Umbris Rye Imperial Stout
# 2107                    Forest Fire Imperial Smoked Rye
# 2274                     Ten Fidy Imperial Stout (2007)
# 2108                               Bad Axe Imperial IPA
# 430                                        Abrasive Ale
#
#                                  style  ounces
# 7                   English Barleywine    16.0
# 143             Russian Imperial Stout    16.0
# 335                      Baltic Porter    12.0
# 166     American Double / Imperial IPA    12.0
# 178                   Belgian Dark Ale    16.0
# 190             Russian Imperial Stout    16.0
# 196                 English Barleywine    16.0
# 207                 English Barleywine    16.0
# 261     American Double / Imperial IPA    16.0
# 341     American Double / Imperial IPA    12.0
# 348                      Baltic Porter    12.0
# 377   American Double / Imperial Stout    19.2
# 382     American Double / Imperial IPA    19.2
# 423                 American Black Ale    16.0
# 673     American Double / Imperial IPA    12.0
# 702     American Double / Imperial IPA    12.0
# 755                 American Black Ale    12.0
# 1015            Russian Imperial Stout    12.0
# 1017    American Double / Imperial IPA    12.0
# 1271                American Black Ale    16.0
# 1303                       Pumpkin Ale    16.0
# 1605               American Barleywine    12.0
# 1721    American Double / Imperial IPA    12.0
# 1813               American Barleywine     8.4
# 1933            Russian Imperial Stout    12.0
# 2038  American Double / Imperial Stout    16.0
# 2107                          Rye Beer    16.0
# 2274            Russian Imperial Stout    12.0
# 2108    American Double / Imperial IPA    16.0
# 430     American Double / Imperial IPA    16.0

# %%
#Dropped null values, then scatter plot for brew styles and ABV%. English Barley and Russian Imperial have both high and low ABV's.
#I dont know why quadruple quad didnt show up on the dataframe above. Tried to sort from highest to lowest ABV%. Plotted the top 30 ABV's
top_30.plot(kind='scatter', x='style', y='abv', grid=True, figsize=(20,10), 
                       title=f' Correlation of Style and ABV')
plt.grid()
plt.tight_layout()

# %%
# poop_df.plot(kind='scatter', x='style', y='abv', 
#                        title=f' Correlation of Style and ABV')
# plt.grid()

# %%
# state_data = poop_df["state"].value_counts()
# style_data = poop_df["style"].value_counts()
# style_state_data= state_data.add(style_data, fill_value=0)
# style_chart = style_data.plot(kind='bar', facecolor="blue", figsize=(30,5))
# plt.title("Style Brewed Popularity")
# state_chart.set_xlabel("Style")
# state_chart.set_ylabel("Number of Times Brewed")
# plt.show()
# plt.tight_layout

abv_data = poop_df["abv"].value_counts()

# %%
style_data
# Out:
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# Smoked Beer                         1
# Kristalweizen                       1
# Flanders Oud Bruin                  1
# Flanders Red Ale                    1
# Braggot                             1
# Name: style, Length: 99, dtype: int64

# %%
abv_data
# Out:
# 0.050    215
# 0.055    158
# 0.060    125
# 0.065    123
# 0.052    107
#         ...
# 0.128      1
# 0.034      1
# 0.028      1
# 0.094      1
# 0.125      1
# Name: abv, Length: 74, dtype: int64

# %%
# plt.scatter(style_data, abv_data, marker="o", facecolors="red", edgecolors="black",
#             s=style_data, alpha=0.75)

style_data_74 = style_data.nlargest(74)

# %%
style_data_74
# Out:
# American IPA                      424
# American Pale Ale (APA)           245
# American Amber / Red Ale          133
# American Blonde Ale               108
# American Double / Imperial IPA    105
#                                  ...
# Munich Dunkel Lager                 4
# English Strong Ale                  4
# Dunkelweizen                        4
# Quadrupel (Quad)                    4
# Chile Beer                          3
# Name: style, Length: 74, dtype: int64

# %%
#Trying to chart a correlation between the ABV% and number of beers brewed at a higher ABV. This graph can most likely be deleted, just showing what direction I'm trying to go.
#A scatter plot apprently must have equal values, that's why I-ve set it to 74 styles, to equal 74 abv's. -David
plt.scatter(abv_data, style_data_74, marker="o", facecolors="red", edgecolors="black",
            s=abv_data, alpha=0.75)

# %%
# top_30.plot(kind='scatter', x='style', y='abv', grid=True, figsize=(20,20), 
#                        title=f' Correlation of Style and ABV')
# plt.grid()
# plt.tight_layout()

plt.scatter(abv_data, style_data_74, marker="o", facecolors="red", edgecolors="black",
            s=abv_data, alpha=0.75)

# %%
#Scatter plot of all the beer styles and their ABV's. Obviously this needs to be trimmed, I struggled trying to do so.-David
new_poop_df.plot(kind='scatter', x='style', y='abv', grid=True, figsize=(50,10), 
                       title=f' Correlation of Style and ABV')
plt.tight_layout()
