# %%
import re
import pandas as pd
import os
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
beers_csv = "beers.csv"
breweries_csv = "breweries.csv"

beers_df = pd.read_csv(beers_csv)
breweries_df = pd.read_csv(breweries_csv)
beers_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-301e990f4037> in <module>
#       2 breweries_csv = "breweries.csv"
#       3
# ----> 4 beers_df = pd.read_csv(beers_csv)
#       5 breweries_df = pd.read_csv(breweries_csv)
#       6 beers_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File beers.csv does not exist: 'beers.csv'

# %%
breweries_df = breweries_df.rename(columns={"Unnamed: 0":"brewery_id"})
breweries_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4c906ed3c3f9> in <module>
# ----> 1 breweries_df = breweries_df.rename(columns={"Unnamed: 0":"brewery_id"})
#       2 breweries_df
#
# NameError: name 'breweries_df' is not defined

# %%
# pd.merge(beers_df, breweries_df, )
poop_df = breweries_df.merge(beers_df, on="brewery_id")
poop_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d5ba3ce433f1> in <module>
#       1 # pd.merge(beers_df, breweries_df, )
# ----> 2 poop_df = breweries_df.merge(beers_df, on="brewery_id")
#       3 poop_df
#
# NameError: name 'breweries_df' is not defined

# %%
beers_and_breweries = pd.merge(beers_df, 
                               breweries_df, 
                               how='inner', 
                               left_on="brewery_id", 
                               right_on="id", 
                               sort=True,
                               suffixes=('_beer', '_brewery'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2036d40c4bd0> in <module>
# ----> 1 beers_and_breweries = pd.merge(beers_df,
#       2                                breweries_df,
#       3                                how='inner',
#       4                                left_on="brewery_id",
#       5                                right_on="id",
#
# NameError: name 'beers_df' is not defined

# %%
beers.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-77f8d5f3781c> in <module>
# ----> 1 beers.dtypes
#
# NameError: name 'beers' is not defined

# %%
def get_var_category(series):
    unique_count = series.nunique(dropna=False)
    total_count = len(series)
    if pd.api.types.is_numeric_dtype(series):
        return 'Numerical'
    elif pd.api.types.is_datetime64_dtype(series):
        return 'Date'
    elif unique_count==total_count:
        return 'Text (Unique)'
    else:
        return 'Categorical'

def print_categories(df):
    for column_name in df.columns:
        print(column_name, ": ", get_var_category(df[column_name]))

# %%
print_categories(beers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-29f04dd426f6> in <module>
# ----> 1 print_categories(beers)
#
# NameError: name 'beers' is not defined

# %%
brew_group = poop_df.groupby('style')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-4ef78b2a1840> in <module>
# ----> 1 brew_group = poop_df.groupby('style')
#
# NameError: name 'poop_df' is not defined

# %%
count_brew = brew_group['style'].count()

count_brew
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-279b1a4fdb87> in <module>
# ----> 1 count_brew = brew_group['style'].count()
#       2
#       3 count_brew
#
# NameError: name 'brew_group' is not defined

# %%
count_brew.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-c6e72b01b47b> in <module>
# ----> 1 count_brew.describe()
#
# NameError: name 'count_brew' is not defined

# %%
state_data = poop_df["state"].value_counts()
style_data = poop_df["style"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-509661d9896f> in <module>
# ----> 1 state_data = poop_df["state"].value_counts()
#       2 style_data = poop_df["style"].value_counts()
#
# NameError: name 'poop_df' is not defined

# %%
style_state_data= state_data.add(style_data, fill_value=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-792b1ad45c45> in <module>
# ----> 1 style_state_data= state_data.add(style_data, fill_value=0)
#
# NameError: name 'state_data' is not defined

# %%
style_state_data.plot(kind="bar", facecolor="blue", figsize=(40,5))
plt.title("Style of Beer Brewed")
plt.ylabel("Number of Times Brewed")
plt.xlabel("Style of Brew")
plt.show
plt.tight_layout
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e94b7d3e5de4> in <module>
# ----> 1 style_state_data.plot(kind="bar", facecolor="blue", figsize=(40,5))
#       2 plt.title("Style of Beer Brewed")
#       3 plt.ylabel("Number of Times Brewed")
#       4 plt.xlabel("Style of Brew")
#       5 plt.show
#
# NameError: name 'style_state_data' is not defined

# %%
style_chart = style_data.plot(kind='bar', facecolor="blue", figsize=(30,5))
plt.title("Style Brewed Popularity")
state_chart.set_xlabel("Style")
state_chart.set_ylabel("Number of Times Brewed")
plt.show()
plt.tight_layout
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-72669195e3c6> in <module>
# ----> 1 style_chart = style_data.plot(kind='bar', facecolor="blue", figsize=(30,5))
#       2 plt.title("Style Brewed Popularity")
#       3 state_chart.set_xlabel("Style")
#       4 state_chart.set_ylabel("Number of Times Brewed")
#       5 plt.show()
#
# NameError: name 'style_data' is not defined

# %%
state_group = poop_df.groupby('state')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-c0eba49474ca> in <module>
# ----> 1 state_group = poop_df.groupby('state')
#
# NameError: name 'poop_df' is not defined

# %%
state_group.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-9de764e255b4> in <module>
# ----> 1 state_group.count()
#
# NameError: name 'state_group' is not defined

# %%
state_chart = state_group.plot(kind="bar", title="State Brewery Popularity")
state_chart.set_xlabel("state")
state_chart.set_ylabel("Number of Breweries")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-c02ff1f5201e> in <module>
# ----> 1 state_chart = state_group.plot(kind="bar", title="State Brewery Popularity")
#       2 state_chart.set_xlabel("state")
#       3 state_chart.set_ylabel("Number of Breweries")
#       4 plt.show()
#
# NameError: name 'state_group' is not defined

# %%
state_data = poop_df["state"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-fcd701d9085c> in <module>
# ----> 1 state_data = poop_df["state"].value_counts()
#
# NameError: name 'poop_df' is not defined

# %%
state_chart = state_data.plot(kind='bar', facecolor="blue", figsize=(10,5))
plt.title("State Brewery Popularity")
state_chart.set_xlabel("State")
state_chart.set_ylabel("Number of Breweries")
plt.show()
plt.tight_layout
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-d0e8c9d8be85> in <module>
# ----> 1 state_chart = state_data.plot(kind='bar', facecolor="blue", figsize=(10,5))
#       2 plt.title("State Brewery Popularity")
#       3 state_chart.set_xlabel("State")
#       4 state_chart.set_ylabel("Number of Breweries")
#       5 plt.show()
#
# NameError: name 'state_data' is not defined

# %%
beer_group.df = poop_df.groupby(['state', 'style'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-7bb52a4e6dd3> in <module>
# ----> 1 beer_group.df = poop_df.groupby(['state', 'style'])
#
# NameError: name 'poop_df' is not defined

# %%
beer_sum = beer_group.df.sum()
beer_sum.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-597a2602c41d> in <module>
# ----> 1 beer_sum = beer_group.df.sum()
#       2 beer_sum.head()
#
# NameError: name 'beer_group' is not defined

# %%
state_and_style = poop_df[["state","style"]]
state_and_style = state_and_style.set_index("state")
state_and_style
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-730531489dd2> in <module>
# ----> 1 state_and_style = poop_df[["state","style"]]
#       2 state_and_style = state_and_style.set_index("state")
#       3 state_and_style
#
# NameError: name 'poop_df' is not defined

# %%
state_and_style_df = pd.DataFrame(state_and_style)

# %%
plt.style.use('ggplot')

state_and_style_df.groupby(['state', 'style'])\
      .style.count().unstack().plot.bar(legend=True, figsize=(10,5))

# %%
state_and_style.groupby('state').count()
# Out:
#        style
# state
#  AK       25
#  AL       10
#  AR        5
#  AZ       47
#  CA      183
#  CO      265
#  CT       27
#  DC        8
#  DE        2
#  FL       58
#  GA       16
#  HI       27
#  IA       30
#  ID       30
#  IL       91
#  IN      139
#  KS       23
#  KY       21
#  LA       19
#  MA       82
#  MD       21
#  ME       27
#  MI      162
#  MN       55
#  MO       42
#  MS       11
#  MT       40
#  NC       59
#  ND        3
#  NE       25
#  NH        8
#  NJ        8
#  NM       14
#  NV       11
#  NY       74
#  OH       49
#  OK       19
#  OR      125
#  PA      100
#  RI       27
#  SC       14
#  SD        7
#  TN        6
#  TX      130
#  UT       26
#  VA       40
#  VT       27
#  WA       68
#  WI       87
#  WV        2
#  WY       15

# %%
poop_df.nlargest(5, ['abv'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-15ab58ea82a0> in <module>
# ----> 1 poop_df.nlargest(5, ['abv'])
#
# NameError: name 'poop_df' is not defined
